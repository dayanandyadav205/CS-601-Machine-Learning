# %%
#Distance from the origin (Euclidean Formula)
import numpy as np

# define a n-dimensional vector A
A = np.array([1, 2])

# Calculate the Euclidean distance from th origin (L2 Norm)
distance = np.linalg.norm(A) #linalg = Linear Algebra

print("Euclidean distance from origin:", distance)
# Out:
# Euclidean distance from origin: 7.416198487095663

# %%
# Import math Library
import math

# Return the square root of different numbers
print (math.sqrt(5))
# Out:
# 2.23606797749979

# %%
#Distance from the origin (Euclidean Formula) n-D vector
import numpy as np

# define a n-dimensional vector A
A = np.array([1, 2, 3, 4, 5])
B = np.array([6, 7, 8, 9, 10])

#Calculate the Difference Vector
difference = A - B

difference
# Out:
# array([-5, -5, -5, -5, -5])

# %%
distance = np.linalg.norm(difference)

print("Euclidean distance between A and B:", distance)
# Out:
# Euclidean distance between A and B: 11.180339887498949

# %%
import plotly.graph_objects as go

# Define the vector
vector = [3, 4, 5]

# Create the 3D plot
fig = go.Figure(data=[go.Scatter3d(
    x=[0, vector[0]],
    y=[0, vector[1]],
    z=[0, vector[2]],
)])


# Show the plot
fig.show()

# %%
#Mean Centering
import numpy as np
import matplotlib.pyplot as plt

#Generate random 2D data with 100 points
data = np.random.rand(100, 2)

data
# Out:
# array([[0.46217608, 0.20849618],
#        [0.43040174, 0.17866035],
#        [0.96609323, 0.30604503],
#        [0.68957354, 0.87219804],
#        [0.76042315, 0.92461036],
#        [0.05663691, 0.8069559 ],
#        [0.58944723, 0.81448726],
#        [0.88431253, 0.02952853],
#        [0.13740376, 0.20471444],
#        [0.55659446, 0.00779237],
#        [0.39931893, 0.30653311],
#        [0.35360215, 0.40110708],
#        [0.40465101, 0.15756678],
#        [0.7869308 , 0.17427916],
#        [0.40673715, 0.72573173],
#        [0.96130234, 0.99421835],
#        [0.40699812, 0.37849497],
#        [0.97973774, 0.9184053 ],
#        [0.08097816, 0.8950091 ],
#        [0.4393598 , 0.00948599],
#        [0.24740645, 0.44945893],
#        [0.71115107, 0.42273096],
#        [0.63911321, 0.49341763],
#        [0.57094352, 0.31709088],
#        [0.7479884 , 0.70115159],
#        [0.19197935, 0.8962738 ],
#        [0.6408    , 0.34298173],
#        [0.11203795, 0.59303953],
#        [0.44388666, 0.74854648],
#        [0.44667437, 0.48629914],
#        [0.10322081, 0.96586454],
#        [0.83926973, 0.85604453],
#        [0.23317039, 0.71585637],
#        [0.85697289, 0.11623035],
#        [0.71332179, 0.69506233],
#        [0.94088379, 0.48055855],
#        [0.61109345, 0.97118159],
#        [0.59767103, 0.66667671],
#        [0.46731606, 0.48798204],
#        [0.32740623, 0.09852962],
#        [0.76685011, 0.42504185],
#        [0.157082  , 0.15026872],
#        [0.45744356, 0.82238873],
#        [0.08938356, 0.78355654],
#        [0.01904706, 0.4002356 ],
#        [0.94406586, 0.76965473],
#        [0.21231085, 0.05622945],
#        [0.08901293, 0.54029623],
#        [0.49353422, 0.77915944],
#        [0.47446315, 0.93654315],
#        [0.8070152 , 0.49223257],
#        [0.71375536, 0.95004933],
#        [0.71885401, 0.39064941],
#        [0.21589082, 0.0443691 ],
#        [0.67711099, 0.77107685],
#        [0.05439028, 0.65620863],
#        [0.46608873, 0.61274661],
#        [0.9077941 , 0.60287753],
#        [0.38036884, 0.67458683],
#        [0.90592479, 0.91735805],
#        [0.49004914, 0.04770867],
#        [0.14405692, 0.75408416],
#        [0.52125825, 0.20626397],
#        [0.6164133 , 0.81693067],
#        [0.26280635, 0.67792126],
#        [0.33157276, 0.09705475],
#        [0.78010982, 0.4811826 ],
#        [0.19550386, 0.31158728],
#        [0.25175789, 0.73319424],
#        [0.77016515, 0.94260837],
#        [0.22590964, 0.10960067],
#        [0.35430381, 0.51706405],
#        [0.90134549, 0.54077992],
#        [0.83438413, 0.20035462],
#        [0.61941471, 0.57749089],
#        [0.8078905 , 0.29754561],
#        [0.49068611, 0.61631946],
#        [0.10120791, 0.08135267],
#        [0.41940518, 0.43494314],
#        [0.42557199, 0.87440814],
#        [0.69351359, 0.96989284],
#        [0.19183281, 0.12866169],
#        [0.66945058, 0.46579277],
#        [0.44858473, 0.76040434],
#        [0.27237672, 0.37863602],
#        [0.99743308, 0.38535119],
#        [0.17353584, 0.5065747 ],
#        [0.6123091 , 0.42093314],
#        [0.74950046, 0.3483895 ],
#        [0.41563983, 0.18271976],
#        [0.98557506, 0.23805398],
#        [0.66343268, 0.64703841],
#        [0.41123787, 0.72711476],
#        [0.77824326, 0.50060149],
#        [0.22687295, 0.4996032 ],
#        [0.30823754, 0.16395873],
#        [0.11183173, 0.93532789],
#        [0.38920039, 0.86418537],
#        [0.22151826, 0.98667396],
#        [0.39438677, 0.2773061 ]])

# %%
#Plot the original data
plt.scatter(data[:, 0], data[:, 1])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Before Mean Centering")
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Calculate the mean of data
data_mean = np.mean(data, axis=0)

print(data_mean)

#perform mean centering
centered_data = data - data_mean
# Out:
# [0.50003899 0.52300442]

# %%
#Plot the mean centered data
plt.scatter(centered_data[:, 0], centered_data[:, 1], color="orange")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("After Mean Centering")
# Out:
# Text(0.5, 1.0, 'After Mean Centering')

# %%
#Mean Centering
import numpy as np
import matplotlib.pyplot as plt

#Generate random 2D data with 100 points
data = np.random.rand(100, 2)

data

#Plot the original data
plt.scatter(data[:, 0], data[:, 1])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("Before Mean Centering")

#Calculate the mean of data
data_mean = np.mean(data, axis=0)

print(data_mean)

#perform mean centering
centered_data = data - data_mean

#Plot the mean centered data
plt.scatter(centered_data[:, 0], centered_data[:, 1], color="orange")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("After Mean Centering")
# Out:
# [0.49132903 0.51554473]
# Text(0.5, 1.0, 'After Mean Centering')
