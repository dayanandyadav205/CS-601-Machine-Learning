# %%
 student_list = ["Jamie", "Vicky", "DeShawn", "Tae"]
 print(student_list)
# Out:
# ['Jamie', 'Vicky', 'DeShawn', 'Tae']

# %%
list1 = [[1, 2, 3],
 [1, 4, 9],
 [1, 8, 27]]

# %%
 print(list1)
# Out:
# [[1, 2, 3], [1, 4, 9], [1, 8, 27]]
