# %%
import numpy
matrix =  [[1, 2], 
          [3, 4], 
          [5, 6]]
print("\nGiven Matrix is:", matrix)
print("\n The Transpose Matrix is:")
print(numpy.transpose(matrix))
# Out:
# Given Matrix is: [[1, 2], [3, 4], [5, 6]]
#
#  The Transpose Matrix is:
# [[1 3 5]
#  [2 4 6]]
